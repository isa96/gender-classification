# %% [markdown]
# # Import Library

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D

# %% [markdown]
# # Data Exploration

# %%
images_folder = '/home/images/'
listimg = os.listdir(images_folder)
EXAMPLE_IMG = plt.imread(images_folder + np.random.choice(listimg))

# %%
EXAMPLE_IMG.shape
# Out:
# (218, 178, 3)

# %%
# import dataset
df_attr = pd.read_csv('/home/list_attr_celeba.csv')
df_attr.set_index('image_id', inplace=True)
df_attr.replace(to_replace=-1, value=0, inplace=True) #replace -1 by 0
df_attr.shape
# Out:
# (202599, 40)

# %%
try:
  df_attr.loc[listimg]
except Exception as e:
  print(e)
# Out:
# "['182793(1).jpg', '182809(1).jpg', '182912(1).jpg', '182943(1).jpg', '183005(1).jpg', '183018(1).jpg', '183050(1).jpg', '183111(1).jpg', '183121(1).jpg', '183145(1).jpg', '189132(1).jpg', '189297(1).jpg', '189324(1).jpg', '189512(1).jpg', '189513(1).jpg', '189581(1).jpg', '189651(1).jpg'] not in index"

# %% [markdown]
# Ditemukan beberapa file duplikat yang ditandai oleh (1) di akhir nama file

# %%
uniquelist = [img for img in listimg if not img.endswith("(1).jpg")]
uniquelist
# Out:
# ['000051.jpg',
#  '000065.jpg',
#  '000052.jpg',
#  '000166.jpg',
#  '000198.jpg',
#  '000201.jpg',
#  '000240.jpg',
#  '000282.jpg',
#  '000352.jpg',
#  '000409.jpg',
#  '000414.jpg',
#  '000439.jpg',
#  '000444.jpg',
#  '000474.jpg',
#  '000525.jpg',
#  '000545.jpg',
#  '000572.jpg',
#  '000559.jpg',
#  '000608.jpg',
#  '000653.jpg',
#  '000716.jpg',
#  '000771.jpg',
#  '000810.jpg',
#  '000798.jpg',
#  '000845.jpg',
#  '000858.jpg',
#  '000873.jpg',
#  '000922.jpg',
#  '000989.jpg',
#  '001140.jpg',
#  '001161.jpg',
#  '001218.jpg',
#  '001242.jpg',
#  '001248.jpg',
#  '001256.jpg',
#  '001270.jpg',
#  '001295.jpg',
#  '001401.jpg',
#  '001519.jpg',
#  '001509.jpg',
#  '001665.jpg',
#  '001613.jpg',
#  '001637.jpg',
#  '001782.jpg',
#  '001708.jpg',
#  '001800.jpg',
#  '001894.jpg',
#  '001921.jpg',
#  '001983.jpg',
#  '002085.jpg',
#  '002125.jpg',
#  '002134.jpg',
#  '002150.jpg',
#  '002197.jpg',
#  '002202.jpg',
#  '002223.jpg',
#  '002256.jpg',
#  '002310.jpg',
#  '002362.jpg',
#  '002389.jpg',
#  '002427.jpg',
#  '002415.jpg',
#  '002443.jpg',
#  '002450.jpg',
#  '002456.jpg',
#  '002502.jpg',
#  '002525.jpg',
#  '002527.jpg',
#  '002592.jpg',
#  '002556.jpg',
#  '002598.jpg',
#  '002653.jpg',
#  '002662.jpg',
#  '002663.jpg',
#  '002693.jpg',
#  '002698.jpg',
#  '002808.jpg',
#  '002747.jpg',
#  '002834.jpg',
#  '002903.jpg',
#  '003026.jpg',
#  '003103.jpg',
#  '003148.jpg',
#  '003252.jpg',
#  '003306.jpg',
#  '003354.jpg',
#  '003363.jpg',
#  '003416.jpg',
#  '003427.jpg',
#  '003461.jpg',
#  '003477.jpg',
#  '003516.jpg',
#  '003543.jpg',
#  '003630.jpg',
#  '003632.jpg',
#  '003652.jpg',
#  '003683.jpg',
#  '003747.jpg',
#  '003776.jpg',
#  '003847.jpg',
#  '003928.jpg',
#  '003940.jpg',
#  '003959.jpg',
#  '003976.jpg',
#  '004007.jpg',
#  '004026.jpg',
#  '004109.jpg',
#  '004132.jpg',
#  '004136.jpg',
#  '004174.jpg',
#  '004178.jpg',
#  '004205.jpg',
#  '004311.jpg',
#  '004326.jpg',
#  '004353.jpg',
#  '004405.jpg',
#  '004409.jpg',
#  '004422.jpg',
#  '004449.jpg',
#  '004460.jpg',
#  '004540.jpg',
#  '004557.jpg',
#  '004584.jpg',
#  '004599.jpg',
#  '004623.jpg',
#  '004663.jpg',
#  '004726.jpg',
#  '004757.jpg',
#  '004728.jpg',
#  '004762.jpg',
#  '004779.jpg',
#  '004886.jpg',
#  '005020.jpg',
#  '005089.jpg',
#  '005091.jpg',
#  '005158.jpg',
#  '005249.jpg',
#  '005256.jpg',
#  '005308.jpg',
#  '005334.jpg',
#  '005363.jpg',
#  '005390.jpg',
#  '005406.jpg',
#  '005458.jpg',
#  '005558.jpg',
#  '005594.jpg',
#  '005608.jpg',
#  '005707.jpg',
#  '005722.jpg',
#  '005799.jpg',
#  '005822.jpg',
#  '005851.jpg',
#  '006020.jpg',
#  '006102.jpg',
#  '006107.jpg',
#  '006184.jpg',
#  '006236.jpg',
#  '006219.jpg',
#  '006254.jpg',
#  '006260.jpg',
#  '006386.jpg',
#  '006422.jpg',
#  '006490.jpg',
#  '006511.jpg',
#  '006596.jpg',
#  '006713.jpg',
#  '006764.jpg',
#  '006783.jpg',
#  '006801.jpg',
#  '006825.jpg',
#  '006854.jpg',
#  '006947.jpg',
#  '006949.jpg',
#  '007002.jpg',
#  '007027.jpg',
#  '007032.jpg',
#  '007106.jpg',
#  '007111.jpg',
#  '007119.jpg',
#  '007135.jpg',
#  '007137.jpg',
#  '007145.jpg',
#  '007291.jpg',
#  '007335.jpg',
#  '007357.jpg',
#  '007383.jpg',
#  '007450.jpg',
#  '007484.jpg',
#  '007498.jpg',
#  '007505.jpg',
#  '007538.jpg',
#  '007566.jpg',
#  '007572.jpg',
#  '007573.jpg',
#  '007586.jpg',
#  '007588.jpg',
#  '007609.jpg',
#  '007644.jpg',
#  '007723.jpg',
#  '007725.jpg',
#  '007738.jpg',
#  '007754.jpg',
#  '007875.jpg',
#  '007943.jpg',
#  '008021.jpg',
#  '008038.jpg',
#  '008067.jpg',
#  '008096.jpg',
#  '008151.jpg',
#  '008126.jpg',
#  '008184.jpg',
#  '008185.jpg',
#  '008264.jpg',
#  '008283.jpg',
#  '008294.jpg',
#  '008304.jpg',
#  '008412.jpg',
#  '008343.jpg',
#  '008426.jpg',
#  '008438.jpg',
#  '008488.jpg',
#  '008539.jpg',
#  '008601.jpg',
#  '008639.jpg',
#  '008708.jpg',
#  '008812.jpg',
#  '008880.jpg',
#  '008886.jpg',
#  '008899.jpg',
#  '008921.jpg',
#  '008931.jpg',
#  '008968.jpg',
#  '009102.jpg',
#  '009138.jpg',
#  '009195.jpg',
#  '009238.jpg',
#  '009253.jpg',
#  '009287.jpg',
#  '009295.jpg',
#  '009327.jpg',
#  '009376.jpg',
#  '009355.jpg',
#  '009391.jpg',
#  '009482.jpg',
#  '009593.jpg',
#  '009613.jpg',
#  '009664.jpg',
#  '009722.jpg',
#  '009750.jpg',
#  '009740.jpg',
#  '009781.jpg',
#  '009883.jpg',
#  '009782.jpg',
#  '009920.jpg',
#  '009934.jpg',
#  '009979.jpg',
#  '009997.jpg',
#  '010066.jpg',
#  '010102.jpg',
#  '010124.jpg',
#  '010187.jpg',
#  '010130.jpg',
#  '010242.jpg',
#  '010312.jpg',
#  '010345.jpg',
#  '010447.jpg',
#  '010475.jpg',
#  '010485.jpg',
#  '010509.jpg',
#  '010512.jpg',
#  '010530.jpg',
#  '010539.jpg',
#  '010561.jpg',
#  '010562.jpg',
#  '010713.jpg',
#  '010791.jpg',
#  '010825.jpg',
#  '010852.jpg',
#  '010925.jpg',
#  '010941.jpg',
#  '011027.jpg',
#  '011088.jpg',
#  '011094.jpg',
#  '011108.jpg',
#  '011127.jpg',
#  '011252.jpg',
#  '011262.jpg',
#  '011297.jpg',
#  '011300.jpg',
#  '011316.jpg',
#  '011326.jpg',
#  '011514.jpg',
#  '011529.jpg',
#  '011543.jpg',
#  '011548.jpg',
#  '011628.jpg',
#  '011662.jpg',
#  '011728.jpg',
#  '011770.jpg',
#  '011816.jpg',
#  '011946.jpg',
#  '011916.jpg',
#  '011969.jpg',
#  '011981.jpg',
#  '012046.jpg',
#  '012055.jpg',
#  '012066.jpg',
#  '012102.jpg',
#  '012295.jpg',
#  '012298.jpg',
#  '012354.jpg',
#  '012365.jpg',
#  '012369.jpg',
#  '012408.jpg',
#  '012542.jpg',
#  '012605.jpg',
#  '012653.jpg',
#  '012764.jpg',
#  '012830.jpg',
#  '012878.jpg',
#  '012886.jpg',
#  '012915.jpg',
#  '012930.jpg',
#  '013022.jpg',
#  '013037.jpg',
#  '013041.jpg',
#  '013077.jpg',
#  '013085.jpg',
#  '013091.jpg',
#  '013318.jpg',
#  '013351.jpg',
#  '013392.jpg',
#  '013419.jpg',
#  '013420.jpg',
#  '013503.jpg',
#  '013529.jpg',
#  '013606.jpg',
#  '013726.jpg',
#  '013788.jpg',
#  '013839.jpg',
#  '013953.jpg',
#  '014027.jpg',
#  '014043.jpg',
#  '014062.jpg',
#  '014065.jpg',
#  '014092.jpg',
#  '014098.jpg',
#  '014139.jpg',
#  '014157.jpg',
#  '014269.jpg',
#  '014275.jpg',
#  '014279.jpg',
#  '014306.jpg',
#  '014325.jpg',
#  '014368.jpg',
#  '014390.jpg',
#  '014403.jpg',
#  '014466.jpg',
#  '014541.jpg',
#  '014543.jpg',
#  '014577.jpg',
#  '014682.jpg',
#  '014701.jpg',
#  '014711.jpg',
#  '014731.jpg',
#  '014827.jpg',
#  '014846.jpg',
#  '014908.jpg',
#  '014925.jpg',
#  '014938.jpg',
#  '014950.jpg',
#  '014969.jpg',
#  '015112.jpg',
#  '015163.jpg',
#  '015231.jpg',
#  '015245.jpg',
#  '015267.jpg',
#  '015455.jpg',
#  '015481.jpg',
#  '015606.jpg',
#  '015696.jpg',
#  '015799.jpg',
#  '015784.jpg',
#  '015882.jpg',
#  '015874.jpg',
#  '015907.jpg',
#  '015926.jpg',
#  '015958.jpg',
#  '015965.jpg',
#  '015979.jpg',
#  '016074.jpg',
#  '016075.jpg',
#  '016092.jpg',
#  '016124.jpg',
#  '016160.jpg',
#  '016173.jpg',
#  '016177.jpg',
#  '016217.jpg',
#  '016249.jpg',
#  '016258.jpg',
#  '016359.jpg',
#  '016370.jpg',
#  '016372.jpg',
#  '016406.jpg',
#  '016410.jpg',
#  '016504.jpg',
#  '016514.jpg',
#  '016537.jpg',
#  '016516.jpg',
#  '016605.jpg',
#  '016612.jpg',
#  '016633.jpg',
#  '016646.jpg',
#  '016759.jpg',
#  '016823.jpg',
#  '016875.jpg',
#  '016848.jpg',
#  '017018.jpg',
#  '017023.jpg',
#  '017154.jpg',
#  '017157.jpg',
#  '017191.jpg',
#  '017297.jpg',
#  '017298.jpg',
#  '017324.jpg',
#  '017366.jpg',
#  '017360.jpg',
#  '017438.jpg',
#  '017468.jpg',
#  '017502.jpg',
#  '017512.jpg',
#  '017559.jpg',
#  '017645.jpg',
#  '017656.jpg',
#  '017738.jpg',
#  '017810.jpg',
#  '017966.jpg',
#  '017975.jpg',
#  '017995.jpg',
#  '018035.jpg',
#  '018060.jpg',
#  '018102.jpg',
#  '018061.jpg',
#  '018103.jpg',
#  '018224.jpg',
#  '018263.jpg',
#  '018341.jpg',
#  '018412.jpg',
#  '018428.jpg',
#  '018448.jpg',
#  '018505.jpg',
#  '018536.jpg',
#  '018636.jpg',
#  '018640.jpg',
#  '018646.jpg',
#  '018648.jpg',
#  '018658.jpg',
#  '018730.jpg',
#  '018739.jpg',
#  '018802.jpg',
#  '018891.jpg',
#  '019000.jpg',
#  '019053.jpg',
#  '019082.jpg',
#  '019117.jpg',
#  '019157.jpg',
#  '019169.jpg',
#  '019252.jpg',
#  '019268.jpg',
#  '019271.jpg',
#  '019426.jpg',
#  '019504.jpg',
#  '019484.jpg',
#  '019522.jpg',
#  '019550.jpg',
#  '019560.jpg',
#  '019677.jpg',
#  '019693.jpg',
#  '019721.jpg',
#  '019743.jpg',
#  '019758.jpg',
#  '019814.jpg',
#  '019874.jpg',
#  '019895.jpg',
#  '019959.jpg',
#  '019998.jpg',
#  '020254.jpg',
#  '020158.jpg',
#  '020394.jpg',
#  '020411.jpg',
#  '020470.jpg',
#  '020542.jpg',
#  '020656.jpg',
#  '020708.jpg',
#  '021029.jpg',
#  '021102.jpg',
#  '021161.jpg',
#  '021162.jpg',
#  '021165.jpg',
#  '021185.jpg',
#  '021190.jpg',
#  '021192.jpg',
#  '021228.jpg',
#  '021264.jpg',
#  '021369.jpg',
#  '021380.jpg',
#  '021462.jpg',
#  '021481.jpg',
#  '021487.jpg',
#  '021502.jpg',
#  '021508.jpg',
#  '021521.jpg',
#  '021537.jpg',
#  '021659.jpg',
#  '021675.jpg',
#  '021688.jpg',
#  '021690.jpg',
#  '021722.jpg',
#  '021728.jpg',
#  '021760.jpg',
#  '021796.jpg',
#  '021798.jpg',
#  '021849.jpg',
#  '021882.jpg',
#  '021920.jpg',
#  '021948.jpg',
#  '021962.jpg',
#  '022019.jpg',
#  '022079.jpg',
#  '022086.jpg',
#  '022115.jpg',
#  '022144.jpg',
#  '022156.jpg',
#  '022243.jpg',
#  '022264.jpg',
#  '022369.jpg',
#  '022370.jpg',
#  '022448.jpg',
#  '022449.jpg',
#  '022466.jpg',
#  '022523.jpg',
#  '022566.jpg',
#  '022569.jpg',
#  '022584.jpg',
#  '022589.jpg',
#  '022600.jpg',
#  '022666.jpg',
#  '022672.jpg',
#  '022697.jpg',
#  '022706.jpg',
#  '022764.jpg',
#  '022775.jpg',
#  '022871.jpg',
#  '022960.jpg',
#  '022967.jpg',
#  '023006.jpg',
#  '023013.jpg',
#  '023035.jpg',
#  '023075.jpg',
#  '023080.jpg',
#  '023137.jpg',
#  '023192.jpg',
#  '023484.jpg',
#  '023524.jpg',
#  '023648.jpg',
#  '023668.jpg',
#  '023673.jpg',
#  '023695.jpg',
#  '023719.jpg',
#  '023728.jpg',
#  '023736.jpg',
#  '023788.jpg',
#  '023824.jpg',
#  '023838.jpg',
#  '023957.jpg',
#  '023997.jpg',
#  '024030.jpg',
#  '024069.jpg',
#  '024091.jpg',
#  '024094.jpg',
#  '024111.jpg',
#  '024125.jpg',
#  '024178.jpg',
#  '024241.jpg',
#  '024276.jpg',
#  '024310.jpg',
#  '024388.jpg',
#  '024391.jpg',
#  '024408.jpg',
#  '024417.jpg',
#  '024436.jpg',
#  '024441.jpg',
#  '024473.jpg',
#  '024498.jpg',
#  '024567.jpg',
#  '024582.jpg',
#  '024596.jpg',
#  '024628.jpg',
#  '024645.jpg',
#  '024651.jpg',
#  '024675.jpg',
#  '024703.jpg',
#  '024706.jpg',
#  '024709.jpg',
#  '024775.jpg',
#  '024791.jpg',
#  '024844.jpg',
#  '024846.jpg',
#  '024858.jpg',
#  '024878.jpg',
#  '024882.jpg',
#  '024904.jpg',
#  '024916.jpg',
#  '024924.jpg',
#  '024952.jpg',
#  '025080.jpg',
#  '025101.jpg',
#  '025126.jpg',
#  '025136.jpg',
#  '025139.jpg',
#  '025233.jpg',
#  '025321.jpg',
#  '025342.jpg',
#  '025333.jpg',
#  '025343.jpg',
#  '025345.jpg',
#  '025373.jpg',
#  '025393.jpg',
#  '025413.jpg',
#  '025504.jpg',
#  '025588.jpg',
#  '025630.jpg',
#  '025642.jpg',
#  '025662.jpg',
#  '025676.jpg',
#  '025693.jpg',
#  '025703.jpg',
#  '025731.jpg',
#  '025727.jpg',
#  '025775.jpg',
#  '025808.jpg',
#  '025813.jpg',
#  '025877.jpg',
#  '025875.jpg',
#  '025988.jpg',
#  '025995.jpg',
#  '026041.jpg',
#  '026066.jpg',
#  '026154.jpg',
#  '026267.jpg',
#  '026382.jpg',
#  '026299.jpg',
#  '026391.jpg',
#  '026421.jpg',
#  '026473.jpg',
#  '026492.jpg',
#  '026566.jpg',
#  '026572.jpg',
#  '026590.jpg',
#  '026592.jpg',
#  '026630.jpg',
#  '026811.jpg',
#  '026851.jpg',
#  '026818.jpg',
#  '026898.jpg',
#  '026930.jpg',
#  '026985.jpg',
#  '026945.jpg',
#  '027002.jpg',
#  '027043.jpg',
#  '027076.jpg',
#  '027119.jpg',
#  '027132.jpg',
#  '027139.jpg',
#  '027166.jpg',
#  '027230.jpg',
#  '027238.jpg',
#  '027277.jpg',
#  '027292.jpg',
#  '027359.jpg',
#  '027434.jpg',
#  '027415.jpg',
#  '027459.jpg',
#  '027468.jpg',
#  '027470.jpg',
#  '027481.jpg',
#  '027891.jpg',
#  '027672.jpg',
#  '027966.jpg',
#  '027993.jpg',
#  '027994.jpg',
#  '028000.jpg',
#  '028014.jpg',
#  '028028.jpg',
#  '028038.jpg',
#  '028097.jpg',
#  '028126.jpg',
#  '028131.jpg',
#  '028150.jpg',
#  '028251.jpg',
#  '028290.jpg',
#  '028284.jpg',
#  '028445.jpg',
#  '028467.jpg',
#  '028494.jpg',
#  '028520.jpg',
#  '028651.jpg',
#  '028612.jpg',
#  '028665.jpg',
#  '028684.jpg',
#  '028730.jpg',
#  '028740.jpg',
#  '028768.jpg',
#  '028872.jpg',
#  '028876.jpg',
#  '028889.jpg',
#  '028894.jpg',
#  '028972.jpg',
#  '029005.jpg',
#  '029163.jpg',
#  '029211.jpg',
#  '029328.jpg',
#  '029337.jpg',
#  '029399.jpg',
#  '029409.jpg',
#  '029511.jpg',
#  '029623.jpg',
#  '029631.jpg',
#  '029649.jpg',
#  '029670.jpg',
#  '029701.jpg',
#  '029732.jpg',
#  '029736.jpg',
#  '029738.jpg',
#  '029806.jpg',
#  '029814.jpg',
#  '029860.jpg',
#  '029926.jpg',
#  '029954.jpg',
#  '029967.jpg',
#  '030048.jpg',
#  '030013.jpg',
#  '030087.jpg',
#  '030223.jpg',
#  '030253.jpg',
#  '030263.jpg',
#  '030340.jpg',
#  '030379.jpg',
#  '030446.jpg',
#  '030448.jpg',
#  '030463.jpg',
#  '030484.jpg',
#  '030546.jpg',
#  '030560.jpg',
#  '030561.jpg',
#  '030577.jpg',
#  '030584.jpg',
#  '030644.jpg',
#  '030655.jpg',
#  '030700.jpg',
#  '030742.jpg',
#  '030774.jpg',
#  '030797.jpg',
#  '030819.jpg',
#  '030830.jpg',
#  '030922.jpg',
#  '030935.jpg',
#  '030938.jpg',
#  '031016.jpg',
#  '031020.jpg',
#  '031132.jpg',
#  '031139.jpg',
#  '031264.jpg',
#  '031272.jpg',
#  '031273.jpg',
#  '031292.jpg',
#  '031335.jpg',
#  '031417.jpg',
#  '031499.jpg',
#  '031518.jpg',
#  '031520.jpg',
#  '031605.jpg',
#  '031715.jpg',
#  '031724.jpg',
#  '031729.jpg',
#  '031738.jpg',
#  '031766.jpg',
#  '031792.jpg',
#  '031808.jpg',
#  '031842.jpg',
#  '032036.jpg',
#  '032102.jpg',
#  '032153.jpg',
#  '032164.jpg',
#  '032179.jpg',
#  '032200.jpg',
#  '032211.jpg',
#  '032274.jpg',
#  '032310.jpg',
#  '032352.jpg',
#  '032356.jpg',
#  '032400.jpg',
#  '032533.jpg',
#  '032541.jpg',
#  '032575.jpg',
#  '032626.jpg',
#  '032752.jpg',
#  '032748.jpg',
#  '032794.jpg',
#  '032867.jpg',
#  '032881.jpg',
#  '032911.jpg',
#  '032960.jpg',
#  '032966.jpg',
#  '033080.jpg',
#  '033196.jpg',
#  '033200.jpg',
#  '033237.jpg',
#  '033251.jpg',
#  '033348.jpg',
#  '033448.jpg',
#  '033412.jpg',
#  '033436.jpg',
#  '033501.jpg',
#  '033580.jpg',
#  '033599.jpg',
#  '033651.jpg',
#  '033687.jpg',
#  '033697.jpg',
#  '033699.jpg',
#  '033764.jpg',
#  '033798.jpg',
#  '033826.jpg',
#  '033833.jpg',
#  '033857.jpg',
#  '034063.jpg',
#  '034083.jpg',
#  '034093.jpg',
#  '034132.jpg',
#  '034227.jpg',
#  '034244.jpg',
#  '034254.jpg',
#  '034284.jpg',
#  '034371.jpg',
#  '034520.jpg',
#  '034317.jpg',
#  '034553.jpg',
#  '034594.jpg',
#  '034676.jpg',
#  '034681.jpg',
#  '034741.jpg',
#  '034757.jpg',
#  '034795.jpg',
#  '034817.jpg',
#  '034850.jpg',
#  '034919.jpg',
#  '034966.jpg',
#  '034982.jpg',
#  '035037.jpg',
#  '035039.jpg',
#  '035059.jpg',
#  '035062.jpg',
#  '035083.jpg',
#  '035084.jpg',
#  '035158.jpg',
#  '035166.jpg',
#  '035174.jpg',
#  '035250.jpg',
#  '035265.jpg',
#  '035286.jpg',
#  '035353.jpg',
#  '035377.jpg',
#  '035380.jpg',
#  '035562.jpg',
#  '035407.jpg',
#  '035576.jpg',
#  '035593.jpg',
#  '035690.jpg',
#  '035810.jpg',
#  '035801.jpg',
#  '035840.jpg',
#  '035964.jpg',
#  '036090.jpg',
#  '036141.jpg',
#  '036247.jpg',
#  '036300.jpg',
#  '036341.jpg',
#  '036412.jpg',
#  '036415.jpg',
#  '036521.jpg',
#  '036558.jpg',
#  '036589.jpg',
#  '036669.jpg',
#  '036679.jpg',
#  '036714.jpg',
#  '036770.jpg',
#  '036793.jpg',
#  '036799.jpg',
#  '036824.jpg',
#  '036840.jpg',
#  '036842.jpg',
#  '036907.jpg',
#  '036943.jpg',
#  '037061.jpg',
#  '037043.jpg',
#  '037121.jpg',
#  '037132.jpg',
#  '037143.jpg',
#  '037168.jpg',
#  '037188.jpg',
#  '037224.jpg',
#  '037274.jpg',
#  '037295.jpg',
#  '037361.jpg',
#  '037368.jpg',
#  '037369.jpg',
#  '037371.jpg',
#  '037398.jpg',
#  '037429.jpg',
#  '037461.jpg',
#  '037469.jpg',
#  '037476.jpg',
#  '037637.jpg',
#  '037638.jpg',
#  '037644.jpg',
#  '037682.jpg',
#  '037686.jpg',
#  '037733.jpg',
#  '037763.jpg',
#  '037766.jpg',
#  '037804.jpg',
#  '037857.jpg',
#  '037874.jpg',
#  '037938.jpg',
#  '037942.jpg',
#  '037956.jpg',
#  '037961.jpg',
#  '037993.jpg',
#  '038009.jpg',
#  '038030.jpg',
#  '038086.jpg',
#  '038072.jpg',
#  '038111.jpg',
#  '038150.jpg',
#  '038200.jpg',
#  '038208.jpg',
#  '038228.jpg',
#  '038229.jpg',
#  '038355.jpg',
#  '038299.jpg',
#  '038311.jpg',
#  '038415.jpg',
#  '038428.jpg',
#  '038438.jpg',
#  '038447.jpg',
#  '038459.jpg',
#  '038462.jpg',
#  '038477.jpg',
#  '038577.jpg',
#  '038606.jpg',
#  '038631.jpg',
#  '038681.jpg',
#  '038684.jpg',
#  '038747.jpg',
#  '038765.jpg',
#  '038770.jpg',
#  '038775.jpg',
#  '038818.jpg',
#  '038856.jpg',
#  '038871.jpg',
#  '038892.jpg',
#  '038917.jpg',
#  '038974.jpg',
#  '038998.jpg',
#  '039055.jpg',
#  '039075.jpg',
#  '039140.jpg',
#  '039213.jpg',
#  '039238.jpg',
#  '039267.jpg',
#  '039374.jpg',
#  '039391.jpg',
#  '039418.jpg',
#  '039511.jpg',
#  '039520.jpg',
#  '039537.jpg',
#  '039552.jpg',
#  '039594.jpg',
#  '039600.jpg',
#  '039656.jpg',
#  '039657.jpg',
#  '039753.jpg',
#  '039762.jpg',
#  '039801.jpg',
#  '039836.jpg',
#  '039870.jpg',
#  '039876.jpg',
#  '039895.jpg',
#  '039905.jpg',
#  '039923.jpg',
#  ...]

# %%
# Filter df atribut dengan list gambar yang unik
df_unique = df_attr.loc[uniquelist]

# %% [markdown]
# **Lihat gambar random dari dataset**

# %%
def contohgambar(imagelist):
  random_img = np.random.choice(imagelist)
  random_img_path = images_folder + random_img
  img = plt.imread(random_img_path)
  plt.imshow(img)
  print(df_unique.loc[random_img_path.split('/')[-1]][['Smiling','Male','Black_Hair']]) #some attributes

# %%
contohgambar(uniquelist)
# Out:
# Smiling       0
# Male          1
# Black_Hair    0
# Name: 098718.jpg, dtype: int64

# %% [markdown]
# **Distribusi Atribut**

# %%
# # Laki-laki atau perempuan
counts = df_unique['Male'].value_counts()

# Create a bar plot
plt.barh(counts.index, counts.values, color='c')

# Set the title and axis labels
plt.title('Laki-laki atau Perempuan')
plt.xlabel('Count')
plt.ylabel('Gender')
# Out:
# Text(0, 0.5, 'Gender')

# %% [markdown]
# # 2. Split Data to Train Validation, Test

# %%
def create_train_test(data):
    X = data.drop('Male', axis=1)
    y = data['Male']
    _, valtest, train, valtes = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

    _, _, val, test = train_test_split(valtest, valtes, test_size=1/3, random_state=42, stratify=valtes)

    return train, val, test

# %%
train, val, test = create_train_test(df_unique)

# %%
def prosesdata(data):
    images = []
    for i in range(len(data)):
        img = plt.imread(images_folder + data.index[i])
        images.append(img / 255)
    y_ = tf.keras.utils.to_categorical(data)
    return np.array(images) , y_

# %%
trainX, trainy = prosesdata(train)
valX, valy = prosesdata(val)
testX, testy = prosesdata(test)

# %% [markdown]
# # 3. Build Model

# %%
# Import InceptionV3 Model
tl_model = tf.keras.applications.ResNet50V2(weights='imagenet',
                        include_top=False,
                        input_shape=(218, 178, 3))

print("number of layers:", len(tl_model.layers))
#inc_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 6s 0us/step
# number of layers: 190

# %%
tl_model.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 218, 178, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 224, 184, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 109, 89, 64)  9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 111, 91, 64)  0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 55, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 55, 45, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 55, 45, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 55, 45, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 57, 47, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 55, 45, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 55, 45, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 55, 45, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 55, 45, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 55, 45, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 57, 47, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 55, 45, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 55, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 55, 45, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 55, 45, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 55, 45, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 57, 47, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 23, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 23, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 23, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 23, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 23, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 23, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 23, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 23, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 23, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 23, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 23, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 23, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 23, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 23, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 23, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 23, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 23, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 23, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 23, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 23, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 23, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 23, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 23, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 12, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 12, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 12, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 12, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 12, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 12, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 12, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 12, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 6, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 6, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 6, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 6, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 6, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 6, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 8, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 6, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 6, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 6, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 6, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 6, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 8, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 6, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 6, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 6, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 6, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 8, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 6, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 6, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 6, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
# Lock initial layers to do not be trained
for layer in tl_model.layers[:-40]:
    layer.trainable = False
for layer in tl_model.layers[-40:]:
    layer.trainable = True

#Adding custom Layers
x = tl_model.output
x = Flatten()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
predictions = Dense(2, activation="softmax")(x)

# creating the final model
model = Model(inputs=tl_model.input, outputs=predictions)


# compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 218, 178, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 224, 184, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 109, 89, 64)  9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 111, 91, 64)  0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 55, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 55, 45, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 55, 45, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 55, 45, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 57, 47, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 55, 45, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 55, 45, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 55, 45, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 55, 45, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 55, 45, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 57, 47, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 55, 45, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 55, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 55, 45, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 55, 45, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 55, 45, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 57, 47, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 23, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 23, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 23, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 23, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 23, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 23, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 23, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 23, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 23, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 23, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 23, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 23, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 23, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 23, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 23, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 23, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 23, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 23, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 23, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 23, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 23, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 23, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 23, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 25, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 12, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 12, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 12, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 12, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 12, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 12, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 12, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 12, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 12, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 12, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 12, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 12, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 14, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 6, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 6, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 6, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 6, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 6, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 6, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 8, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 6, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 6, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 6, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 6, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 6, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 8, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 6, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 6, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 6, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 6, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 8, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 6, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 6, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 6, 2048)   0           ['post_bn[0][0]']
#
#  flatten_3 (Flatten)            (None, 86016)        0           ['post_relu[0][0]']
#
#  dense_9 (Dense)                (None, 256)          22020352    ['flatten_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 512)          131584      ['dropout_3[0][0]']
#
#  dense_11 (Dense)               (None, 2)            1026        ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 45,717,762
# Trainable params: 37,387,010
# Non-trainable params: 8,330,752
# __________________________________________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath='/home/model/ResNetV2noaugmentation.h5',
                               verbose=1, save_best_only=True)

# %%
hist = model.fit(trainX, trainy
                     , validation_data = (valX, valy)
                      , epochs= 20
                      , callbacks=[checkpointer]
                      , verbose=1
                    )
# Out:
# Epoch 1/20
# 110/110 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.8883
# Epoch 1: val_loss improved from inf to 0.21060, saving model to /home/model/ResNetV2noaugmentation.h5
# 110/110 [==============================] - 15s 104ms/step - loss: 0.3191 - accuracy: 0.8883 - val_loss: 0.2106 - val_accuracy: 0.9320
# Epoch 2/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9785
# Epoch 2: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0546 - accuracy: 0.9786 - val_loss: 0.2407 - val_accuracy: 0.9310
# Epoch 3/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 0.9923
# Epoch 3: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0242 - accuracy: 0.9923 - val_loss: 0.2381 - val_accuracy: 0.9400
# Epoch 4/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9940
# Epoch 4: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0152 - accuracy: 0.9940 - val_loss: 0.3408 - val_accuracy: 0.9280
# Epoch 5/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0291 - accuracy: 0.9891
# Epoch 5: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0292 - accuracy: 0.9889 - val_loss: 0.3100 - val_accuracy: 0.9430
# Epoch 6/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9894
# Epoch 6: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 79ms/step - loss: 0.0253 - accuracy: 0.9894 - val_loss: 0.2919 - val_accuracy: 0.9360
# Epoch 7/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9934
# Epoch 7: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0226 - accuracy: 0.9934 - val_loss: 0.2392 - val_accuracy: 0.9410
# Epoch 8/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9940
# Epoch 8: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.4283 - val_accuracy: 0.9190
# Epoch 9/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9908
# Epoch 9: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0326 - accuracy: 0.9909 - val_loss: 0.5416 - val_accuracy: 0.8820
# Epoch 10/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9946
# Epoch 10: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0145 - accuracy: 0.9946 - val_loss: 0.3190 - val_accuracy: 0.9500
# Epoch 11/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 11: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 79ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.2705 - val_accuracy: 0.9480
# Epoch 12/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9971
# Epoch 12: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.2970 - val_accuracy: 0.9460
# Epoch 13/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9960
# Epoch 13: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0090 - accuracy: 0.9960 - val_loss: 0.3596 - val_accuracy: 0.9390
# Epoch 14/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 14: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.3500 - val_accuracy: 0.9420
# Epoch 15/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9943
# Epoch 15: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.4224 - val_accuracy: 0.9380
# Epoch 16/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9931
# Epoch 16: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 79ms/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.3120 - val_accuracy: 0.9380
# Epoch 17/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9989
# Epoch 17: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.4273 - val_accuracy: 0.9330
# Epoch 18/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 18: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 79ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.3941 - val_accuracy: 0.9500
# Epoch 19/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9983
# Epoch 19: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.9425 - val_accuracy: 0.9170
# Epoch 20/20
# 109/110 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9946
# Epoch 20: val_loss did not improve from 0.21060
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.6371 - val_accuracy: 0.9430

# %%
# Plot loss function value through epochs
plt.figure(figsize=(18, 4))
plt.plot(hist.history['loss'], label = 'train')
plt.plot(hist.history['val_loss'], label = 'valid')
plt.legend()
plt.title('Loss Function')
plt.show()

# %%
# Plot accuracy through epochs
plt.figure(figsize=(18, 4))
plt.plot(hist.history['accuracy'], label = 'train')
plt.plot(hist.history['val_accuracy'], label = 'valid')
plt.legend()
plt.title('Accuracy')
plt.show()

# %%
with open('/home/history/ResNetV2noaugmentation.pkl', 'wb') as file:
    pickle.dump(hist.history, file)

# %% [markdown]
# # Evaluasi

# %%
model = tf.keras.models.load_model('/home/model/ResNetV2noaugmentation.h5')

# %%
model.evaluate(testX, testy)
# Out:
# 16/16 [==============================] - 2s 61ms/step - loss: 0.1710 - accuracy: 0.9340
# [0.1710122525691986, 0.9340000152587891]

# %%
pred = model.predict(testX)
# Out:
# 16/16 [==============================] - 1s 41ms/step

# %%
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(testy, axis=1)

# %%
false_predicted = []
for i in range(len(testX)):
    if y_pred[i] != y_true[i]:
        false_predicted.append((testX[i], y_pred[i]))

# %%
def plot_kesalahan():
    randnum = np.random.choice(np.arange(len(false_predicted)),8, replace=False)
    fig, axes = plt.subplots(2, 4)

    # Flatten the axes array for easier iteration
    axes = axes.flatten()
    
    # Plot each image in the corresponding subplot
    for i, idx in enumerate(randnum):
        axes[i].imshow(false_predicted[idx][0], cmap='gray')
        axes[i].set_title(f'Predicted {false_predicted[idx][1]}')
        axes[i].axis('off')

    # Adjust the spacing between subplots
    plt.tight_layout()

    # Display the figure
    plt.show()

# %%
plot_kesalahan()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Perempuan','Laki-laki'])
disp.plot()
plt.show()
